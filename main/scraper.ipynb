# %%
import os
import json

from tools.scraper import Scraper

# %%
print(os.environ.get('GCP_SERVICE_ACCOUNT_KEY_PATH'))
# export GCP_SERVICE_ACCOUNT_KEY_PATH="/Users/wingston/code/radiant-voyage-419117-520b39a1e789.json"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.environ.put('GCP_SERVICE_ACCOUNT_KEY_PATH','/Users/wingston/code/radiant-voyage-419117-520b39a1e789.json')
#       2 print(os.environ.get('GCP_SERVICE_ACCOUNT_KEY_PATH'))
#       3 # export GCP_SERVICE_ACCOUNT_KEY_PATH="/Users/wingston/code/radiant-voyage-419117-520b39a1e789.json"
#
# AttributeError: '_Environ' object has no attribute 'put'

# %%
scraper = Scraper(channel_id='UCcZr0Thj63wzIA-Z4N2h2Xg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scraper = Scraper(channel_id='UCcZr0Thj63wzIA-Z4N2h2Xg')
#
# File ~/code/genai-stack/fantano-knowledge-graph/src/main/tools/scraper.py:25, in Scraper.__init__(self, channel_id, playlist_id)
#      23 def __init__(self, channel_id: str = None, playlist_id: str = None) -> None:
# ---> 25     credentials = service_account.Credentials.from_service_account_file(
#      26             os.environ.get('GCP_SERVICE_ACCOUNT_KEY_PATH')
#      27         )
#      28     self.client = storage.Client(credentials=credentials)
#      30     self.service_account = os.environ.get('GCP_SERVICE_ACCOUNT_KEY_PATH')
#
# File ~/code/genai-stack/venv/lib/python3.10/site-packages/google/oauth2/service_account.py:258, in Credentials.from_service_account_file(cls, filename, **kwargs)
#     246 @classmethod
#     247 def from_service_account_file(cls, filename, **kwargs):
#     248     """Creates a Credentials instance from a service account json file.
#     249
#     250     Args:
#    (...)
#     256             credentials.
#     257     """
# --> 258     info, signer = _service_account_info.from_filename(
#     259         filename, require=["client_email", "token_uri"]
#     260     )
#     261     return cls._from_signer_and_info(signer, info, **kwargs)
#
# File ~/code/genai-stack/venv/lib/python3.10/site-packages/google/auth/_service_account_info.py:78, in from_filename(filename, require, use_rsa_signer)
#      64 def from_filename(filename, require=None, use_rsa_signer=True):
#      65     """Reads a Google service account JSON file and returns its parsed info.
#      66
#      67     Args:
#    (...)
#      76             info and a signer instance.
#      77     """
# ---> 78     with io.open(filename, "r", encoding="utf-8") as json_file:
#      79         data = json.load(json_file)
#      80         return data, from_dict(data, require=require, use_rsa_signer=use_rsa_signer)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
scraper.channel_id
# Out:
# 'UCt7fwAhXDy3oNFTAzF2o8Pw'

# %%
with open("resources/playlist_ids.json") as json_file:
    playlists = json.load(json_file)

# %%
playlists
# Out:
# {'classics': 'PLP4CSgl7K7or_7JI7RsEsptyS4wfLFGIN',
#  'electronic': 'PLP4CSgl7K7ormBIO138tYonB949PHnNcP',
#  'hip hop': 'PLP4CSgl7K7ormX2pL9h0inES2Ub630NoL',
#  'worst to best': 'PLP4CSgl7K7opkZ3eKAs1J_parHzPofQH4'}

# %%
titles_to_load = ['electronic', 'worst to best']

# %%
def scraper_sequence(title: str, playlist_id: str) -> None:
    scraper = Scraper(channel_id='UCt7fwAhXDy3oNFTAzF2o8Pw')
    scraper.playlist_id = playlist_id
    scraper._scraped_video_info = None
    print(title)
    print(scraper.playlist_id)

    print("creating CSV file with video info...")
    # scrape video info for playlist
    scraper.scrape_video_info(videos=[])

    print("uploading CSV file to Storage...")
    # upload to Storage
    scraper.upload_scraped_video_info(file_name=title)

    print("Creating and uploading transcripts...")
    # create and upload transcripts

    scraper.create_and_upload_transcripts(transcripts_folder=title, video_info_file_name=title)

    # ignore failed for now

    print()

# %%
# title = 'classics'
# id = playlists[title]

for title in titles_to_load:
    scraper_sequence(title=title, playlist_id=playlists[title])
# Out:
# electronic
# PLP4CSgl7K7ormBIO138tYonB949PHnNcP
# creating CSV file with video info...
# total results set:  726
# ids retrieved:  50
# ids retrieved:  100
# ids retrieved:  150
# ids retrieved:  200
# ids retrieved:  250
# ids retrieved:  300
# ids retrieved:  350
# ids retrieved:  400
# ids retrieved:  450
# ids retrieved:  500
# ids retrieved:  550
# ids retrieved:  600
# ids retrieved:  650
# ids retrieved:  700
# ids retrieved:  726
# complete
# uploading CSV file to Storage...
# Creating and uploading transcripts...
#
# worst to best
# PLP4CSgl7K7opkZ3eKAs1J_parHzPofQH4
# creating CSV file with video info...
# total results set:  8
# ids retrieved:  8
# complete
# uploading CSV file to Storage...
# Creating and uploading transcripts...
# Progress :  100.0 % |  failed:  0
